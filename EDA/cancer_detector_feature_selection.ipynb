# %%
import numpy as np

from methyldl.deconvolution.feature_selection import compute_feature_ratios

# %%
matrices_cd_uniform_path = "/staging/leuven/stg_00118/methylDL/experiments/pseudobulk/CancerDetector/uniform_prior/pseudobulk_prior_uniform/ios_full_matrices.npz"
matrices_cd_uniform = np.load(matrices_cd_uniform_path, allow_pickle=True)

# %%
matrices_cd_uniform.keys()
# Out:
# KeysView(NpzFile '/staging/leuven/stg_00118/methylDL/experiments/pseudobulk/CancerDetector/uniform_prior/pseudobulk_prior_uniform/ios_full_matrices.npz' with keys: proportions, features_train, features_valid, features_test)

# %%
unif_prop = matrices_cd_uniform["proportions"]
unif_prop.shape
