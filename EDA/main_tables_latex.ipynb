# %%
import numpy
import pandas as pd

# %%
metrics_dismir_softlabels_with_pooling = pd.read_csv(
    "/staging/leuven/stg_00118/methylDL/experiments/ExtendedProportions/pseudobulk/Dismir_Loyfer_205files_U25_attentionClassifier_hg38_dmr_ctype_label_mincpg_4_minlen_10_postfiltered_min_length_50_soft_labels_pooled_jakkard_no_data_leak_d041/pseudobulk/fitted_deconvolvers_unifrorm_multinomial_all_top156_features/callibration/confidence_intervals_summary.csv"
)
metrics_methylbert_softlabels_with_pooling = pd.read_csv(
    "/staging/leuven/stg_00118/methylDL/experiments/ExtendedProportions/pseudobulk/methylBert_Loyfer_205files_U25_attentionClassifier_hg38_dmr_ctype_label_mincpg_4_minlen_10_postfiltered_min_length_50_soft_labels_pooled_jakkard_no_data_leak_d041/pseudobulk/fitted_deconvolvers_unifrorm_multinomial_all_top156features/callibration/confidence_intervals_summary.csv"
)
metrics_lookup_softlabels_with_pooling = pd.read_csv(
    "/staging/leuven/stg_00118/methylDL/experiments/ExtendedProportions/pseudobulk/LookupClassifier_SoftLabels_Ours/pseudobulk/fitted_deconvolvers_unifrorm_multinomial_all_top156features/callibration/confidence_intervals_summary.csv"
)
metrics_dismir_softlabels_without_pooling = pd.read_csv(
    "/staging/leuven/stg_00118/methylDL/experiments/ExtendedProportions/pseudobulk/Dismir_Loyfer_205files_U25_attentionClassifier_hg38_dmr_ctype_label_mincpg_4_minlen_10_postfiltered_min_length_50_soft_labels_NO_POOLING/pseudobulk/fitted_deconvolvers_unifrorm_multinomial_all_top156_features/callibration/confidence_intervals_summary.csv"
)
metrics_methylbert_softlabels_without_pooling = pd.read_csv(
    "/staging/leuven/stg_00118/methylDL/experiments/pseudobulk/methylBert_Loyfer_205files_U25_attentionClassifier_hg38_dmr_ctype_label_mincpg_4_minlen_10_no_data_lea_postfiltered_min_length_50_soft_labels_NOPOOLING_v2/pseudobulk/fitted_deconvolvers_unifrorm_multinomial_all_top156_features/calibration/confidence_intervals_summary.csv"
)
metrics_lookup_softlabels_without_pooling = pd.read_csv(
    "/staging/leuven/stg_00118/methylDL/experiments/ExtendedProportions/pseudobulk/LookupClassifier_SoftLabels_WITHOUTPOOLING/pseudobulk/fitted_deconvolvers_unifrorm_multinomial_all_top156_features/callibration/confidence_intervals_summary.csv"
)
metrics_dismir_hardlabels_diagrej = pd.read_csv(
    "/staging/leuven/stg_00118/methylDL/experiments/ExtendedProportions/pseudobulk/Dismir_Loyfer_205files_U25_attentionClassifier_hg38_dmr_ctype_label_mincpg_4_minlen_10_postfiltered_min_length_50_hard_labels/pseudobulk/fitted_deconvolvers_unifrorm_multinomial_all_diagrej_features/callibration/confidence_intervals_summary.csv"
)
metrics_methylbert_hardlabels_diagrej = pd.read_csv(
    "/staging/leuven/stg_00118/methylDL/experiments/ExtendedProportions/pseudobulk/methylBert_Loyfer_205files_U25_attentionClassifier_hg38_dmr_ctype_label_mincpg_4_minlen_10_postfiltered_min_length_50_hard_labels_minibatch_balanced/pseudobulk/fitted_deconvolvers_unifrorm_multinomial_all_diagrej_features/callibration/confidence_intervals_summary.csv"
)
metrics_lookup_hardlabels_diagrej = pd.read_csv(
    "/staging/leuven/stg_00118/methylDL/experiments/ExtendedProportions/pseudobulk/LookupClassifier_HardLabels/pseudobulk/fitted_deconvolvers_unifrorm_multinomial_all_diagrej_features/callibration/confidence_intervals_summary.csv"
)
metrics_dismir_hardlabels_top156 = pd.read_csv(
    "/staging/leuven/stg_00118/methylDL/experiments/ExtendedProportions/pseudobulk/Dismir_Loyfer_205files_U25_attentionClassifier_hg38_dmr_ctype_label_mincpg_4_minlen_10_postfiltered_min_length_50_hard_labels/pseudobulk/fitted_deconvolvers_unifrorm_multinomial_all_top156_features/callibration/confidence_intervals_summary.csv"
)
metrics_methylbert_hardlabels_top156 = pd.read_csv(
    "/staging/leuven/stg_00118/methylDL/experiments/ExtendedProportions/pseudobulk/methylBert_Loyfer_205files_U25_attentionClassifier_hg38_dmr_ctype_label_mincpg_4_minlen_10_postfiltered_min_length_50_hard_labels_minibatch_balanced/pseudobulk/fitted_deconvolvers_unifrorm_multinomial_all_top156_features/callibration/confidence_intervals_summary.csv"
)
metrics_lookup_hardlabels_top156 = pd.read_csv(
    "/staging/leuven/stg_00118/methylDL/experiments/ExtendedProportions/pseudobulk/LookupClassifier_HardLabels/pseudobulk/fitted_deconvolvers_unifrorm_multinomial_all_top156_features/callibration/confidence_intervals_summary.csv"
)
metrics_cancerdetector_trainfreq = pd.read_csv(
    "/staging/leuven/stg_00118/methylDL/experiments/ExtendedProportions/pseudobulk/CancerDetector/train_freq_prior/pseudobulk/fitted_deconvolvers_unifrorm_multinomial_all_top156_features/callibration/confidence_intervals_summary.csv"
)
metrics_cancerdetector_uniform = pd.read_csv(
    "/staging/leuven/stg_00118/methylDL/experiments/ExtendedProportions/pseudobulk/CancerDetector/uniform_prior/pseudobulk/fitted_deconvolvers_unifrorm_multinomial_all_top156_features/callibration/confidence_intervals_summary.csv"
)
metrics_uxm = pd.read_csv(
    "/staging/leuven/stg_00118/methylDL/experiments/ExtendedProportions/pseudobulk/uxm_results/pseudobulk/calibration_results/confidence_intervals_summary.csv"
)
metrics_dismir_canonicalsoft_diagrej = pd.read_csv(
    "/staging/leuven/stg_00118/methylDL/experiments/ExtendedProportions/pseudobulk/Dismir_Loyfer_205files_U25_attentionClassifier_hg38_dmr_ctype_label_mincpg_4_minlen_10_postfiltered_min_length_50_soft_labels_canonical/pseudobulk/fitted_deconvolvers_unifrorm_multinomial_all_diagback_features/calibration/confidence_intervals_summary.csv"
)
metrics_methylbert_canonicalsoft_diagrej = pd.read_csv(
    "/staging/leuven/stg_00118/methylDL/experiments/ExtendedProportions/pseudobulk/methylBert_Loyfer_205files_U25_attentionClassifier_hg38_dmr_ctype_label_mincpg_4_minlen_10_no_data_leak_d041_postfiltered_min_length_50_soft_labels_canonical/pseudobulk/fitted_deconvolvers_unifrorm_multinomial_all_diagback_features/calibration/confidence_intervals_summary.csv"
)
metrics_dismir_canonicalsoft_top156 = pd.read_csv(
    "/staging/leuven/stg_00118/methylDL/experiments/ExtendedProportions/pseudobulk/Dismir_Loyfer_205files_U25_attentionClassifier_hg38_dmr_ctype_label_mincpg_4_minlen_10_postfiltered_min_length_50_soft_labels_canonical/pseudobulk/fitted_deconvolvers_unifrorm_multinomial_all_top156_features/calibration/confidence_intervals_summary.csv"
)
metrics_methylbert_canonicalsoft_top156 = pd.read_csv(
    "/staging/leuven/stg_00118/methylDL/experiments/ExtendedProportions/pseudobulk/methylBert_Loyfer_205files_U25_attentionClassifier_hg38_dmr_ctype_label_mincpg_4_minlen_10_no_data_leak_d041_postfiltered_min_length_50_soft_labels_canonical/pseudobulk/fitted_deconvolvers_unifrorm_multinomial_all_top156_features/calibration/confidence_intervals_summary.csv"
)

# %%
metrics = {
    "dismir": {
        "hard_labels": {
            "diagrej": metrics_dismir_hardlabels_diagrej,
            "top156": metrics_dismir_hardlabels_top156,
        },
        "canonical_soft_labels": {
            "diagrej": metrics_dismir_canonicalsoft_diagrej,
            "top156": metrics_dismir_canonicalsoft_top156,
        },
        "soft_labels_without_pooling": metrics_dismir_softlabels_without_pooling,
        "soft_labels_with_pooling": metrics_dismir_softlabels_with_pooling,
    },
    "methylbert": {
        "hard_labels": {
            "diagrej": metrics_methylbert_hardlabels_diagrej,
            "top156": metrics_methylbert_hardlabels_top156,
        },
        "canonical_soft_labels": {
            "diagrej": metrics_methylbert_canonicalsoft_diagrej,
            "top156": metrics_methylbert_canonicalsoft_top156,
        },
        "soft_labels_without_pooling": metrics_methylbert_softlabels_without_pooling,
        "soft_labels_with_pooling": metrics_methylbert_softlabels_with_pooling,
    },
    "lookup": {
        "hard_labels": {
            "diagrej": metrics_lookup_hardlabels_diagrej,
            "top156": metrics_lookup_hardlabels_top156,
        },
        "soft_labels_without_pooling": metrics_lookup_softlabels_without_pooling,
        "soft_labels_with_pooling": metrics_lookup_softlabels_with_pooling,
    },
    "cancerdetector": {
        "train_freq_prior": metrics_cancerdetector_trainfreq,
        "uniform_prior": metrics_cancerdetector_uniform,
    },
    "uxm": metrics_uxm,
}

# %%
COL_CRITERION = "kl"

# %%
# first we select the best pair of (deconvolver, calibration method) for each (classifier, labeling)
best_metrics = {}
for clf in ["dismir", "methylbert", "lookup"]:
    best_metrics[clf] = {"cal": {}, "uncal": {}}
    for labeling_type in metrics[clf].keys():
        if labeling_type in ["hard_labels", "canonical_soft_labels"]:
            best_metrics[clf]["cal"][labeling_type] = {}
            best_metrics[clf]["uncal"][labeling_type] = {}
            for feature_set in ["diagrej", "top156"]:
                df = metrics[clf][labeling_type][feature_set]
                best_row = df.loc[df[COL_CRITERION].idxmax()]
                best_metrics[clf]["cal"][labeling_type][feature_set] = best_row.to_dict()

                df_uncal = df[df["calibration_method"] == "uncalibrated"]
                best_row_uncal = df_uncal.loc[df_uncal[COL_CRITERION].idxmax()]
                best_metrics[clf]["uncal"][labeling_type][feature_set] = best_row_uncal.to_dict()
        else:
            df = metrics[clf][labeling_type]
            best_row = df.loc[df[COL_CRITERION].idxmax()]
            best_metrics[clf]["cal"][labeling_type] = best_row.to_dict()
            
            df_uncal = df[df["calibration_method"] == "uncalibrated"]
            best_row_uncal = df_uncal.loc[df_uncal[COL_CRITERION].idxmax()]
            best_metrics[clf]["uncal"][labeling_type] = best_row_uncal.to_dict()

# %%
best_metrics
# Out:
# {'dismir': {'cal': {'hard_labels': {'diagrej': {'deconvolver': 'nnls',
#      'calibration_method': 'uncalibrated',
#      'cosine_sim': 0.9797810106865686,
#      'kl': 0.299255541712195,
#      'kl_ci_lower': 0.2941342118965356,
#      'kl_ci_upper': 0.3042517858730412,
#      'kl_per_sample': '[0.04285023 0.08485929 0.88233863 ... 0.00389561 0.23752822 0.10894376]',
#      'loa_lower': -0.0365827357443336,
#      'loa_upper': 0.0365827357443336,
#      'loa_width': 0.0731654714886673,
#      'mae': 0.0043865286584186,
#      'mae_ci_lower': 0.0043597197790025,
#      'mae_ci_upper': 0.004413386819346,
#      'mae_per_sample': '[0.00215103 0.00385924 0.00409636 ... 0.00113474 0.00773846 0.00601779]',
#      'max_error': 0.8972840079979357,
#      'mse': 0.0003483694844301,
#      'mse_ci_lower': 0.0003398416416441,
#      'mse_ci_upper': 0.000357351369981,
#      'mse_per_sample': '[4.95562541e-05 1.48388374e-04 1.04531512e-04 ... 1.08913104e-05\n 3.46937299e-04 3.21947695e-04]',
# ...

# %%
# print the table
classifiers_print = {"dismir": "{\shortstack[l]{Dismir\cite{li2021dismir} \\(CNN+LSTM)}}"}
