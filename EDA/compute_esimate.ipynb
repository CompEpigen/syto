# %%
import pandas as pd
import numpy as np

# %%
compute_log = pd.read_csv("hpc_job_logs_20260501_100037/combined_summary.tsv", sep="\t")

# %%
print(compute_log.to_string())
# Out:
#    Cluster       JobID               JobName             Partition  NodeList  NNodes  NCPUS  ReqMem(MB)  MaxRSS(MB)  GPUs   Elapsed Timelimit  CPUEff(%)  MemEff(%)
# 0     wice  66499137_0            pseudobulk  batch_sapphirerapids  q16c05n2       1     20       50000    23408.57     0  00:24:37  01:00:00        4.9       46.8
# 1     wice  66499137_1            pseudobulk  batch_sapphirerapids  q16c07n1       1     20       50000    26400.85     0  00:26:02  01:00:00        4.9       52.8
# 2     wice  66499137_2            pseudobulk  batch_sapphirerapids  q16c07n1       1     20       50000    23067.91     0  00:30:05  01:00:00        4.9       46.1
# 3     wice  66499137_3            pseudobulk  batch_sapphirerapids  q16c07n4       1     20       50000    27049.11     0  00:27:40  01:00:00        4.9       54.1
# 4     wice  66499137_4            pseudobulk  batch_sapphirerapids  q16c15n2       1     20       50000    32676.40     0  00:26:01  01:00:00        4.9       65.4
# ...
