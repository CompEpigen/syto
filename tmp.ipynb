# %%
import pandas as pd
import pickle
import numpy as np

from syto.data.pseudobulk_generator import PseudobulkGenerator

# %load_ext autoreload
# %autoreload 2

# %%
predicted_reads = pickle.load(open("Data/training_data/methylBert_Loyfer_205files_U25_attentionClassifier_hg38_dmr_ctype_label_mincpg_4_minlen_10_no_data_leak_d041_postfiltered_min_length_50_hard_labels_focal_loss_for_plotting/predicted_reads.pkl", "rb"))

# %%
predicted_reads.keys()
# Out:
# dict_keys(['train', 'valid', 'test'])

# %%
train_predicted_reads = predicted_reads["train"]

# %%
train_predicted_reads.keys()
# Out:
# Index(['chr', 'read_name', 'trimmed_start', 'trimmed_end', 'pattern', 'seq',
#        'name', 'region_start', 'region_end', 'original_label', 'label',
#        'soft_label', 'M', 'U', 'NCPGS', 'M_rate', 'record_M', 'record_U',
#        'record_X', 'dmr_ctype', 'dmr_ctype_matched', 'dmr_ctype_label',
#        'pattern_len', 'prediction_0', 'prediction_1', 'prediction_2',
#        'prediction_3', 'prediction_4', 'prediction_5', 'prediction_6',
#        'prediction_7', 'prediction_8', 'prediction_9', 'prediction_10',
#        'prediction_11', 'prediction_12', 'prediction_13', 'prediction_14',
#        'prediction_15', 'prediction_16', 'prediction_17', 'prediction_18',
#        'prediction_19', 'prediction_20', 'prediction_21', 'prediction_22',
#        'prediction_23', 'prediction_24', 'prediction_25', 'prediction_26',
#        'prediction_27', 'prediction_28', 'prediction_29', 'prediction_30',
#        'prediction_31', 'prediction_32', 'prediction_33', 'prediction_34',
#        'prediction_35', 'prediction_36', 'prediction_37', 'prediction_38',
#        'prediction_39'],
#       dtype='object')

# %%
train_predicted_reads["dmr_ctype_label"].value_counts()
# Out:
# dmr_ctype_label
# 20    149915
# 17    132611
# 29    126974
# 38    109426
# 2     104153
# 8     100427
# 23     98282
# 26     94518
# 5      93058
# 36     92189
# 18     90726
# 31     87293
# 6      85822
# 22     82900
# 21     81209
# 14     80585
# 34     74529
# 30     73512
# 15     73222
# 3      70580
# 35     69629
# 24     68997
# 9      67752
# 27     67440
# 10     66357
# 7      66129
# 1      65902
# 33     64252
# 19     60524
# 16     58379
# 12     57261
# 32     56701
# 13     52941
# 4      50136
# 28     50123
# 25     45443
# 0      25202
# 37     10670
# 11      4345
# Name: count, dtype: int64

# %%
indices_per_class_and_grg = train_predicted_reads.groupby(["original_label", "dmr_ctype_label"]).indices

# %%
train_predicted_reads[["M", "U"]].head()
# Out:
#    M  U
# 0  5  0
# 1  6  0
# 2  6  0
# 3  6  0
# 4  5  1

# %%
train_predicted_reads.columns
# Out:
# Index(['chr', 'read_name', 'trimmed_start', 'trimmed_end', 'pattern', 'seq',
#        'name', 'region_start', 'region_end', 'original_label', 'label',
#        'soft_label', 'M', 'U', 'NCPGS', 'M_rate', 'record_M', 'record_U',
#        'record_X', 'dmr_ctype', 'dmr_ctype_matched', 'dmr_ctype_label',
#        'pattern_len', 'prediction_0', 'prediction_1', 'prediction_2',
#        'prediction_3', 'prediction_4', 'prediction_5', 'prediction_6',
#        'prediction_7', 'prediction_8', 'prediction_9', 'prediction_10',
#        'prediction_11', 'prediction_12', 'prediction_13', 'prediction_14',
#        'prediction_15', 'prediction_16', 'prediction_17', 'prediction_18',
#        'prediction_19', 'prediction_20', 'prediction_21', 'prediction_22',
#        'prediction_23', 'prediction_24', 'prediction_25', 'prediction_26',
#        'prediction_27', 'prediction_28', 'prediction_29', 'prediction_30',
#        'prediction_31', 'prediction_32', 'prediction_33', 'prediction_34',
#        'prediction_35', 'prediction_36', 'prediction_37', 'prediction_38',
#        'prediction_39'],
#       dtype='object')

# %%
result = PseudobulkGenerator.generate_single_pseudobulk(
    n_reads_to_sample=39*40,
    n_gr_groups=39,
    indices_per_class_and_grg=indices_per_class_and_grg,
    read_df = train_predicted_reads,
    target_proportions = np.ones(40) / 40,
    grg_grouping_columns = ["dmr_ctype", "dmr_ctype_label"],
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.cache/pypoetry/virtualenvs/methyldl-eOjiV2TE-py3.13/lib/python3.13/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'methylation_level'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 result = PseudobulkGenerator.generate_single_pseudobulk(
#       2     n_reads_to_sample=39*40,
#       3     n_gr_groups=39,
#       4     indices_per_class_and_grg=indices_per_class_and_grg,
#       5     read_df = train_predicted_reads,
#       6     target_proportions = np.ones(40) / 40,
#       7     grg_grouping_columns = ["dmr_ctype", "dmr_ctype_label"],
#       8 )
#
# File ~/Documents/Scolaire/7_Cesure/2_KU_Leuven/methyldl/syto/data/pseudobulk_generator.py:145, in PseudobulkGenerator.generate_single_pseudobulk(cls, n_reads_to_sample, n_gr_groups, indices_per_class_and_grg, read_df, target_proportions, grg_grouping_columns, columns_to_keep, grg_sampling_type)
#     138 read_ids = _sample_read_ids_from_grouped_dataframe(
#     139     n_samples_per_class_per_grg,
#     140     indices_per_class_and_grg,
#     141     seed=seed,
#     142 )  # shape (actual_n_reads_sampled,)
#     144 # Aggregate the reads by GR group into a feature matrix
# --> 145 aggregated_features = aggregate_predictions_by_grg_optimized(
#     146     read_df, []
#     147 )
#     148 if columns_to_keep is not None:
#     149     aggregated_features = aggregated_features[columns_to_keep]
#
# File ~/Documents/Scolaire/7_Cesure/2_KU_Leuven/methyldl/syto/modelling/prediction_aggregation.py:326, in aggregate_predictions_by_grg_optimized(df, group_cols)
#     324 # Pre-compute weighted values for each prediction column
#     325 for col in prediction_cols:
# --> 326     df[f"_weighted_{col}"] = df[col] * df["_weight"]
#     328 # Build aggregation dictionary
#     329 agg_dict = {}
#
# File ~/.cache/pypoetry/virtualenvs/methyldl-eOjiV2TE-py3.13/lib/python3.13/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/.cache/pypoetry/virtualenvs/methyldl-eOjiV2TE-py3.13/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'methylation_level'
